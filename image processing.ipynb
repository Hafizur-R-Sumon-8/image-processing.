# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('IMG_5581.JPG')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("original image"      )
plt.show()

# %%
img = cv2.imread('IMG_5581.JPG')
plt.title("BGR image")
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.title("Gray Image")
plt.imshow(gray, cmap='gray')

# %%
hist = cv2.calcHist([gray],[0],None,[256],[0,256])
plt.title("Histogram of gray image")
plt.plot(hist)

# %%
kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(gray,kernel,iterations = 1)
dilation = cv2.dilate(gray,kernel,iterations = 1)

# %%
plt.subplot(1, 2, 1)
plt.imshow(erosion, cmap='gray')
plt.title('Erosion')

plt.subplot(1, 2, 2)
plt.imshow(dilation, cmap='gray')
plt.title('Dilation')

plt.show()

# %%
equ = cv2.equalizeHist(gray)

# %%
plt.title("Equalized Image")
plt.imshow(equ, cmap='gray')

# %%
opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN, kernel)
plt.subplot(1, 2, 1)
plt.imshow(opening, cmap='gray')
plt.title('Opening')

closing = cv2.morphologyEx(gray, cv2.MORPH_CLOSE, kernel)
plt.subplot(1, 2, 2)
plt.imshow(closing, cmap='gray')
plt.title('Closing')

plt.show()

# %%
boundary = cv2.subtract(gray, erosion)
plt.subplot(1, 2, 1)
plt.imshow(boundary, cmap='gray')
plt.title('Boundary Extraction')

_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
filling = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=2)
plt.subplot(1, 2, 2)
plt.imshow(filling, cmap='gray')
plt.title('Region Filling')

plt.show()
